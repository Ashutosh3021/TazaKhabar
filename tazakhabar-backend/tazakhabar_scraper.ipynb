# %% [markdown]
# # TazaKhabar Data Scraper Notebook
#
# This notebook scrapes real data from HackerNews and saves it to the SQLite database.
#
# **Prerequisites:**
# - **Python 3.11+ required** (check with `python --version`)
# - Use a Jupyter kernel with Python 3.11+
# - Then run: `pip install -e .`
#
# Run cells in order to:
# 1. Initialize the database and models
# 2. Run the Who Is Hiring scraper
# 3. Run the Top Stories scraper
# 4. Run the Ask HN scraper
# 5. Run the Show HN scraper
# 6. Generate keyword frequencies for trends

# %%
# Check Python version - must be 3.11+
import sys
print(f"Python version: {sys.version}")
if sys.version_info < (3, 11):
    raise RuntimeError("Python 3.11+ required. Please select a different Jupyter kernel.")
# Out:
# Python version: 3.11.6 (tags/v3.11.6:8b6ee5b, Oct  2 2023, 14:57:12) [MSC v.1935 64 bit (AMD64)]

# %%
# Install required packages if needed
import subprocess

def install_deps():
    result = subprocess.run(
        [sys.executable, "-m", "pip", "install", "-e", "."],
        capture_output=True,
        text=True
    )
    if result.returncode == 0:
        print("âœ“ Dependencies installed")
    else:
        print(f"Install warning: {result.stderr[:300]}")

try:
    import sqlalchemy
    print("âœ“ SQLAlchemy available")
except ImportError:
    print("Installing dependencies...")
    install_deps()
# Out:
# âœ“ SQLAlchemy available

# %%
import sys
import os

# Already in backend directory, just add to path
sys.path.insert(0, os.getcwd())

print(f"Working directory: {os.getcwd()}")
# Out:
# Working directory: c:\Users\ashut\Downloads\OnGoingProjects\TazaKhabar\TazaKhabar\tazakhabar-backend

# %%
# Initialize database and import models
import asyncio
from src.db.database import create_all_tables, async_session
from src.db.models import Job, News, Trend, Report

# Initialize tables
await create_all_tables()
print("âœ“ Database initialized")
# Out:
# âœ“ Database initialized

# %%
# Install required packages if needed
import subprocess
import sys

def install_deps():
    result = subprocess.run(
        [sys.executable, "-m", "pip", "install", "-e", "."],
        capture_output=True,
        text=True
    )
    if result.returncode == 0:
        print("âœ“ Dependencies installed")
    else:
        print(f"Install warning: {result.stderr[:200]}")

try:
    import sqlalchemy
    print("âœ“ SQLAlchemy available")
except ImportError:
    print("Installing dependencies...")
    install_deps()
# Out:
# âœ“ SQLAlchemy available

# %%
import sys
import os

# Already in backend directory, just add to path
sys.path.insert(0, os.getcwd())

print(f"Working directory: {os.getcwd()}")
# Out:
# Working directory: c:\Users\ashut\Downloads\OnGoingProjects\TazaKhabar\TazaKhabar\tazakhabar-backend

# %%
# Initialize database and import models
import asyncio
from src.db.database import create_all_tables, async_session
from src.db.models import Job, News, Trend, Report

# Initialize tables
await create_all_tables()
print("âœ“ Database initialized")
# Out:
# âœ“ Database initialized

# %%
# Run the Who Is Hiring scraper
from src.scrapers.who_is_hiring import WhoIsHiringScraper

async def run_wih_scraper():
    scraper = WhoIsHiringScraper()
    result = await scraper.run()
    return result

result = await run_wih_scraper()
print(f"Who Is Hiring scraper result: {result}")
# Out:
# --------------------------------------------------
# >>> [WIH-SCRAPER] Starting Who Is Hiring scraper run
# >>> [WIH-SCRAPER] Step 1: Discovering Who Is Hiring thread via Algolia...
# >>> [WIH-SCRAPER] Found thread ID=22665398: 'Ask HN: Who is hiring right now?'
# >>> [WIH-SCRAPER] Thread 22665398 already processed (last run), skipping.
# Who Is Hiring scraper result: {'collected': 0, 'new': 0}

# %%
# Run the Top Stories scraper
from src.scrapers.top_stories import TopStoriesScraper

async def run_top_stories_scraper():
    scraper = TopStoriesScraper()
    result = await scraper.run()
    return result

result = await run_top_stories_scraper()
print(f"Top Stories scraper result: {result}")
# Out:
# --------------------------------------------------
# >>> [TOP-STORIES] Starting Top Stories scraper run
# >>> [TOP-STORIES] Fetching top 30 story IDs...
# >>> [TOP-STORIES] Fetching 30 story details (parallel)...
# >>> [TOP-STORIES] Fetched 30 stories
# >>> [TOP-STORIES] Filtered to 15 stories with score >= 100
# >>> [TOP-STORIES] Saving 15 stories to database...
# >>> [TOP-STORIES] SUCCESS: 0 NEW items saved!
# >>> [TOP-STORIES] Scraper run completed successfully
# --------------------------------------------------
#
# Top Stories scraper result: {'collected': 15, 'new': 0}

# %%
# Run the Ask HN scraper
from src.scrapers.ask_hn import AskHNScraper

async def run_ask_hn_scraper():
    scraper = AskHNScraper()
    result = await scraper.run()
    return result

result = await run_ask_hn_scraper()
print(f"Ask HN scraper result: {result}")
# Out:
# Ask HN scraper result: {'collected': 28, 'new': 0}

# %%
# Run the Show HN scraper
from src.scrapers.show_hn import ShowHNScraper

async def run_show_hn_scraper():
    scraper = ShowHNScraper()
    result = await scraper.run()
    return result

result = await run_show_hn_scraper()
print(f"Show HN scraper result: {result}")
# Out:
# Show HN scraper result: {'collected': 129, 'new': 0}

# %%
# Verify data in database
import sqlite3

conn = sqlite3.connect('tazakhabar.db')
cursor = conn.cursor()

tables = ['jobs', 'news', 'trends', 'observations']
for table in tables:
    cursor.execute(f'SELECT COUNT(*) FROM {table}')
    count = cursor.fetchone()[0]
    print(f"{table}: {count} rows")

conn.close()
# Out:
# jobs: 23 rows
# news: 382 rows
# trends: 59 rows
# observations: 12 rows

# %%
# Generate keyword frequencies for trends
from src.services.trend_service import compute_keyword_frequencies

async def run_trend_service():
    result = await compute_keyword_frequencies()
    return result

result = await run_trend_service()
print(f"Trend service result: {result}")
# Out:
# Trend service result: [{'keyword': 'lead', 'count': 2, 'percentage_change': 100.0, 'week_start': datetime.datetime(2026, 3, 20, 0, 0), 'week_end': datetime.datetime(2026, 3, 27, 0, 0)}, {'keyword': 'ai', 'count': 66, 'percentage_change': 100.0, 'week_start': datetime.datetime(2026, 3, 20, 0, 0), 'week_end': datetime.datetime(2026, 3, 27, 0, 0)}, {'keyword': 'security', 'count': 6, 'percentage_change': 100.0, 'week_start': datetime.datetime(2026, 3, 20, 0, 0), 'week_end': datetime.datetime(2026, 3, 27, 0, 0)}, {'keyword': 'azure', 'count': 2, 'percentage_change': 100.0, 'week_start': datetime.datetime(2026, 3, 20, 0, 0), 'week_end': datetime.datetime(2026, 3, 27, 0, 0)}, {'keyword': 'staff', 'count': 3, 'percentage_change': 100.0, 'week_start': datetime.datetime(2026, 3, 20, 0, 0), 'week_end': datetime.datetime(2026, 3, 27, 0, 0)}, {'keyword': 'cloud', 'count': 5, 'percentage_change': 100.0, 'week_start': datetime.datetime(2026, 3, 20, 0, 0), 'week_end': datetime.datetime(2026, 3, 27, 0, 0)}, {'keyword': 'backend', 'count': 3, 'percentage_change': 100.0, 'week_start': datetime.datetime(2026, 3, 20, 0, 0), 'week_end': datetime.datetime(2026, 3, 27, 0, 0)}, {'keyword': 'junior', 'count': 6, 'percentage_change': 100.0, 'week_start': datetime.datetime(2026, 3, 20, 0, 0), 'week_end': datetime.datetime(2026, 3, 27, 0, 0)}, {'keyword': 'devops', 'count': 4, 'percentage_change': 100.0, 'week_start': datetime.datetime(2026, 3, 20, 0, 0), 'week_end': datetime.datetime(2026, 3, 27, 0, 0)}, {'keyword': 'openai', 'count': 4, 'percentage_change': 100.0, 'week_start': datetime.datetime(2026, 3, 20, 0, 0), 'week_end': datetime.datetime(2026, 3, 27, 0, 0)}, {'keyword': 'manager', 'count': 3, 'percentage_change': 100.0, 'week_start': datetime.datetime(2026, 3, 20, 0, 0), 'week_end': datetime.datetime(2026, 3, 27, 0, 0)}, {'keyword': 'rust', 'count': 6, 'percentage_change': 100.0, 'week_start': datetime.datetime(2026, 3, 20, 0, 0), 'week_end': datetime.datetime(2026, 3, 27, 0, 0)}, {'keyword': 'ml', 'count': 4, 'percentage_change': 100.0, 'week_start': datetime.datetime(2026, 3, 20, 0, 0), 'week_end': datetime.datetime(2026, 3, 27, 0, 0)}, {'keyword': 'startup', 'count': 2, 'percentage_change': 100.0, 'week_start': datetime.datetime(2026, 3, 20, 0, 0), 'week_end': datetime.datetime(2026, 3, 27, 0, 0)}, {'keyword': 'hybrid', 'count': 3, 'percentage_change': 100.0, 'week_start': datetime.datetime(2026, 3, 20, 0, 0), 'week_end': datetime.datetime(2026, 3, 27, 0, 0)}, {'keyword': 'llm', 'count': 9, 'percentage_change': 100.0, 'week_start': datetime.datetime(2026, 3, 20, 0, 0), 'week_end': datetime.datetime(2026, 3, 27, 0, 0)}, {'keyword': 'remote', 'count': 2, 'percentage_change': 100.0, 'week_start': datetime.datetime(2026, 3, 20, 0, 0), 'week_end': datetime.datetime(2026, 3, 27, 0, 0)}, {'keyword': 'c++', 'count': 2, 'percentage_change': 100.0, 'week_start': datetime.datetime(2026, 3, 20, 0, 0), 'week_end': datetime.datetime(2026, 3, 27, 0, 0)}, {'keyword': 'senior', 'count': 2, 'percentage_change': 100.0, 'week_start': datetime.datetime(2026, 3, 20, 0, 0), 'week_end': datetime.datetime(2026, 3, 27, 0, 0)}, {'keyword': 'postgresql', 'count': 2, 'percentage_change': 100.0, 'week_start': datetime.datetime(2026, 3, 20, 0, 0), 'week_end': datetime.datetime(2026, 3, 27, 0, 0)}, {'keyword': 'api', 'count': 9, 'percentage_change': 100.0, 'week_start': datetime.datetime(2026, 3, 20, 0, 0), 'week_end': datetime.datetime(2026, 3, 27, 0, 0)}, {'keyword': 'serverless', 'count': 1, 'percentage_change': 100.0, 'week_start': datetime.datetime(2026, 3, 20, 0, 0), 'week_end': datetime.datetime(2026, 3, 27, 0, 0)}, {'keyword': 'typescript', 'count': 3, 'percentage_change': 100.0, 'week_start': datetime.datetime(2026, 3, 20, 0, 0), 'week_end': datetime.datetime(2026, 3, 27, 0, 0)}, {'keyword': 'javascript', 'count': 4, 'percentage_change': 100.0, 'week_start': datetime.datetime(2026, 3, 20, 0, 0), 'week_end': datetime.datetime(2026, 3, 27, 0, 0)}, {'keyword': 'react' ...

# %%
# Generate market observation using LLM
from src.services.llm_service import summarize_top_news, generate_observation_text
from src.db.database import async_session
from sqlalchemy import select
from src.db.models import Trend, Observation
from datetime import datetime

# First, summarize unsummarized news
await summarize_top_news(top_n=20)
print("âœ“ News summarization complete")

# Get trending keywords
async with async_session() as session:
    stmt = select(Trend).order_by(Trend.percentage_change.desc()).limit(10)
    result = await session.execute(stmt)
    trends = result.scalars().all()
    
    booming = [t.keyword for t in trends if t.percentage_change > 0]
    declining = [t.keyword for t in trends if t.percentage_change < 0]
    
    print(f"Booming keywords: {booming}")
    print(f"Declining keywords: {declining}")

# Generate observation
if booming or declining:
    observation_text = await generate_observation_text(booming, declining)
    print(f"Observation: {observation_text[:200]}...")
    
    # Save observation
    async with async_session() as session:
        obs = Observation(
            week_start=datetime.utcnow(),
            text=observation_text,
        )
        session.add(obs)
        await session.commit()
    print("âœ“ Observation saved")

# %%
# Final verification - show all table counts
import sqlite3

conn = sqlite3.connect("tazakhabar.db")
cursor = conn.cursor()

cursor.execute("SELECT name FROM sqlite_master WHERE type='table'")
tables = cursor.fetchall()

print("=== Final Database Status ===")
for (table_name,) in tables:
    cursor.execute(f"SELECT COUNT(*) FROM {table_name}")
    count = cursor.fetchone()[0]
    print(f"{table_name}: {count} rows")

print("=== Sample Jobs ===")
cursor.execute("SELECT title, company, location FROM jobs LIMIT 5")
for row in cursor.fetchall():
    print(f"  {row[0]} @ {row[1]} ({row[2]})")

print("=== Sample News ===")
cursor.execute("SELECT title, score, url FROM news LIMIT 5")
for row in cursor.fetchall():
    print(f"  [{row[1]}] {row[0]}")
    print(f"     {row[2]}")

conn.close()
print("[OK] Database verification complete")
# Out:
# === Final Database Status ===
# jobs: 23 rows
# news: 382 rows
# trends: 59 rows
# users: 2 rows
# rate_limits: 4 rows
# reports: 32 rows
# embeddings: 1 rows
# notifications: 0 rows
# observations: 12 rows
# === Sample Jobs ===
#   </code></pre> @  (Onsite)
#   Unknown Position @  (Onsite)
#   PHP, JavaScript, TypeScript, React/Redux, MySQL, Docker, and Elixir. @  (Remote)
#   Shopify | All R&D Roles | Global | Full-time | Onsite/Remote [All remote for now]<p>Shopify is hiring for all R&D roles!<p>We’re an all-in-one commerce platform building tools to start, grow, market, and manage retail businesses of any size (from your fave local shops to behemoths like GymShark and Allbirds).<p>We support over 1 million merchants on our global platform. Our current stack is primarily Ruby, Rails, React, React Native, Go, Kafka, GraphQl, etc.<p>We’re looking for builders who want to solve highly technical problems with really powerful tools.<p>We have open roles for: @  (Remote)
#   HackerRank | Bangalore, India | Fulltime | Senior/Lead Devops Engineer, Lead SDET, Lead Backend Engineers | ONSITE | www.hackerrank.com<p>HackerRank is a Y Combinator alumnus backed by tier one Silicon Valley VCs. We are a skills-based hiring platform that helps companies evaluate technical skills, better. We’re driving a new paradigm shift by eliminating resumes and creating opportunities for hundreds of thousands of programmers worldwide. We have a community of 5M+ developers and 1,000+ customers across industries, and the best part is we are just getting started. Our customers - including VMware, Twitter, Capital One and many other Fortune 100 companies - rely on HackerRank to build strong engineering teams.<p>We're hiring across engineering for the following roles:<p>- Sr/Lead Backend engineers<p>- Sr/Lead Devops engineers<p>- Sr/Lead SDET engineers<p>Good pay with following benefits:<p>- Insurance to all Employees (term life, personal accident, medical, gratuity) along with insurance to their dependents(medical).<p>- Employee stock options, flexible work hours and time off.<p>- Tech talks every week.<p>- Onsite gym, telephone, internet etc. Our pantry is stocked with healthy snacks, fruits, Coffee and free catered lunch every day.<p>- Ping pong, hoverboard, foosball, PS4 and many office celebrations like Mafia games, outings, movie evenings to name a few!<p>Please send an email to anil@hackerrank.com with "WHOISHIRING" in the subject line, with your resume/CV, and a little bit about yourself and relevant experience. @  (Onsite)
# === Sample News ===
#   [403] ArXiv Declares Independence from Cornell
#      https://www.science.org/content/article/arxiv-pioneering-preprint-server-declares-independence-cornell
#   [931] Google details new 24-hour process to sideload unverified Android apps
#      https://arstechnica.com/gadgets/2026/03/google-details-new-24-hour-process-to-sideload-unverified-android-apps/
#   [185] Full Disclosure: A Third (and Fourth) Azure Sign-In Log Bypass Found
#      https://trustedsec.com/blog/full-disclosure-a-third-and-fourth-azure-sign-in-log-bypass-found
#   [177] Drugwars for the TI-82/83/83 Calculators (2011)
#      https://gist.github.com/mattmanning/1002653/b7a1e88479a10eaae3bd5298b8b2c86e16fb4404
#   [357] Push events into a running session with channels
#      https://code.claude.com/docs/en/channels
# [OK] Database verification complete
